# %%
import cv2
import matplotlib.pyplot as plt
import sys
import easyocr
sys.path.append("../ocr")
from ocr import OCR
# %load_ext autoreload
# %autoreload 2
from segmentation import Segmentation
ocr = OCR()
ocr.load_trained_model("../ocr/trained_model.pk1")

for i in range(1700,1800):
    filename = f"../../data/output/passed_1700_1800/{i:04d}_0.jpg"
    image = cv2.imread(f"../../data/output/passed_1700_1800/{i:04d}_0.jpg")
    if image is None:
        image = cv2.imread(f"../../data/output/passed_1700_1800/{i:04d}_1.jpg")
        if image is None:
            continue
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    rois = Segmentation.segment_image(image,gray)

    for roi in rois:
        plt.figure()
        plt.imshow(roi)
        plt.show()
# Out:
# c:\Users\h4z3m\miniconda3\envs\pyenv\Lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator SVC from version 1.3.2 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 26
#      24 plt.figure()
#      25 plt.imshow(roi)
# ---> 26 plt.show()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
#
# ...
