# %%
import cv2
import matplotlib.pyplot as plt
import sys
import easyocr
sys.path.append("../ocr")
from ocr import OCR
# %load_ext autoreload
# %autoreload 2
from segmentation import Segmentation
ocr = OCR()
ocr.load_trained_model("../ocr/trained_model.pk1")

for i in range(800,900):
    filename = f"../../data/Testing_output/passed_800_900/{i:04d}[00].jpg"
    image = cv2.imread(f"../../data/Testing_output/passed_800_900/{i:04d}[00].jpg")
    if image is None:
        image = cv2.imread(f"../../data/Testing_output/passed_800_900/{i:04d}[10].jpg")
        if image is None:
            continue
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    rois = Segmentation.segment_image(image,gray)
    for roi in rois:
        print(ocr.predict(roi))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# c:\Users\h4z3m\miniconda3\envs\pyenv\Lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator SVC from version 1.3.2 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ['م']
# ['م']
# ['م']
# ['أ']
# ['٣']
# ['أ']
# ['ل']
# ['ط']
# ['و']
# ['أ']
# ['أ']
# ['أ']
# ['ر']
# ['١']
# ['٥']
# ['١']
# ['١']
# ['١']
# ['س']
# ['ل']
# ['٦']
# ['٦']
# ['٦']
# ['ع']
# ['ل']
# ['٤']
# ['٦']
# ['٦']
# ['٦']
# ['٦']
# ['١']
# ['م']
# ['٥']
# ['١']
# ['٤']
# ['٥']
# ['٥']
# ['٥']
# ['م']
# ['١']
# ['أ']
# ['٦']
# ['٦']
# ['٦']
# ['٦']
# ['أ']
# ['١']
# ['٥']
# ['٦']
# ['١']
# ['١']
# ['م']
# ['م']
# ['١']
# ['ل']
# ['أ']
# ['أ']
# ['٢']
# ['أ']
# ['٢']
# ['٥']
# ['م']
# ['ى']
# ...
